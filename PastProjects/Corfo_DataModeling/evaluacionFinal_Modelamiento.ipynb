# %%
#!pip install mysqlclient

# %%
#!pip install mariadb

# %%
#!pip install beautifulSoup4
#!pip install pandas
#!pip install sqlalchemy
#!pip install tabula-py
#!pip install xlrd

# %%
import pandas
import matplotlib.pyplot as plt
import requests
from tabula import read_pdf
from bs4 import BeautifulSoup
from sqlalchemy import create_engine
import requests

# %%
# servidor = 129.151.108.83
# puerto   = 3306
# usuario  = admin2
# pass     = admin1234
# database = MayoristaCelulares

engine = create_engine("mariadb+mariadbconnector://admin2:admin1234@129.151.108.83:3306/MayoristaCelulares")

# %%
query1 = pandas.read_sql("SELECT * FROM ventas LEFT JOIN productos on ventas.IDProducto = productos.IDProducto LEFT JOIN categorias on productos.`ID Categoria`=categorias.`ID Categoria`", engine)
display(query1)
# Out:
#       CodigoPedido IDCliente   ID Ciudad IDProducto FechaVenta  Unidades  \
# 0           158957    181215  CIUDAD-600        IP2 2005-01-08      22.0
# 1           158958    181215  CIUDAD-600        IP3 2005-01-08      20.0
# 2           158959    181215  CIUDAD-600        IP4 2005-01-08      20.0
# 3           158960    181215  CIUDAD-600        IP5 2005-01-08      16.0
# 4           158961    181215  CIUDAD-600        IP6 2005-01-08      16.0
# ...            ...       ...         ...        ...        ...       ...
# 25339       184296    181253  CIUDAD-600         MG 2015-12-08      88.0
# 25340       184297    181253  CIUDAD-600         MX 2015-12-08     114.0
# 25341       184298    181253  CIUDAD-600        SXU 2015-12-08      90.0
# 25342       184299    181253  CIUDAD-600        AO1 2015-12-08      86.0
# 25343       184300    181253  CIUDAD-600        LGP 2015-12-08      66.0
#
#       IDProducto ID Categoria NombreProducto  CostoUnitarioCAD  \
# ...

# %%
query1.dtypes
# Out:
# CodigoPedido                 object
# IDCliente                    object
# ID Ciudad                    object
# IDProducto                   object
# FechaVenta           datetime64[ns]
# Unidades                    float64
# IDProducto                   object
# ID Categoria                 object
# NombreProducto               object
# CostoUnitarioCAD            float64
# PrecioUnitarioCAD           float64
# ID Categoria                 object
# Categoria                    object
# dtype: object

# %%
query2 = pandas.read_sql("SELECT * FROM clientes", engine)
display(query2)
# Out:
#    IDCliente NombreCliente
# 0     111225    Jumbo/Easy
# 1     111249        Ct Pal
# 2     141223         Disco
# 3     161217         Éxito
# 4     161229       Unilago
# 5     171219        Tottus
# 6     171251      Infotect
# 7     181215         Jumbo
# 8     181241        Ripley
# 9     181253     Falabella
# 10    191221      Megamaxi

# %%
query2.dtypes
# Out:
# IDCliente        object
# NombreCliente    object
# dtype: object

# %%
df_join_query = query2.join(query1.set_index('IDCliente'), on='IDCliente')
display(df_join_query)
# Out:
#    IDCliente NombreCliente CodigoPedido   ID Ciudad IDProducto FechaVenta  \
# 0     111225    Jumbo/Easy       159037  CIUDAD-200        IP2 2005-01-08
# 0     111225    Jumbo/Easy       159038  CIUDAD-200        IP3 2005-01-08
# 0     111225    Jumbo/Easy       159039  CIUDAD-200        IP4 2005-01-08
# 0     111225    Jumbo/Easy       159040  CIUDAD-200        IP5 2005-01-08
# 0     111225    Jumbo/Easy       159041  CIUDAD-200        IP6 2005-01-08
# ..       ...           ...          ...         ...        ...        ...
# 10    191221      Megamaxi       184184  CIUDAD-700         MG 2015-12-08
# 10    191221      Megamaxi       184185  CIUDAD-700         MX 2015-12-08
# 10    191221      Megamaxi       184186  CIUDAD-700        SXU 2015-12-08
# 10    191221      Megamaxi       184187  CIUDAD-700        AO1 2015-12-08
# 10    191221      Megamaxi       184188  CIUDAD-700        LGP 2015-12-08
#
#     Unidades IDProducto ID Categoria NombreProducto  CostoUnitarioCAD  \
# ...

# %%
pdf_paises = "Paises.pdf"

df_paises_aux = read_pdf(pdf_paises,
pages = ["1"],
multiple_tables = True,
#pandas_options={'skiprows':1}
pandas_options={'header':None},
encoding = 'ISO-8859-1',
stream = False
)

df_paises_aux0 = df_paises_aux[0]


#df_paises_aux0


df_para_concat = [df_paises_aux0]
df_paises = pandas.concat(df_para_concat)

#Promovemos la primera fila como encabezado
df_paises.columns = df_paises.iloc[0]
df_paises = df_paises[1:]

display(df_paises)
# Out:
# 0   ID Pais       Pais
# 1   PAIS-15    Uruguay
# 2   PAIS-32  Argentina
# 3   PAIS-49   Colombia
# 4   PAIS-66      Chile
# 5   PAIS-83       Perú
# 6  PAIS-100    Ecuador

# %%
df_ciudades = pandas.read_excel("Ciudades.xlsx", header=0)
display(df_ciudades)
# Out:
#     ID Ciudad   ID Pais        Ciudad
# 0  CIUDAD-100   PAIS-15    Montevideo
# 1  CIUDAD-200   PAIS-32  Buenos Aires
# 2  CIUDAD-300   PAIS-49        Bogotá
# 3  CIUDAD-400   PAIS-66    Concepción
# 4  CIUDAD-600   PAIS-66      Santiago
# 5  CIUDAD-500   PAIS-83          Lima
# 6  CIUDAD-700  PAIS-100         Quito

# %%
df_join_ciudades_paises = df_ciudades.join(df_paises.set_index('ID Pais'), on = 'ID Pais')
display(df_join_ciudades_paises)

df_join_final = df_join_query.join(df_join_ciudades_paises.set_index('ID Ciudad'), on = 'ID Ciudad')
display(df_join_final)
# Out:
#     ID Ciudad   ID Pais        Ciudad       Pais
# 0  CIUDAD-100   PAIS-15    Montevideo    Uruguay
# 1  CIUDAD-200   PAIS-32  Buenos Aires  Argentina
# 2  CIUDAD-300   PAIS-49        Bogotá   Colombia
# 3  CIUDAD-400   PAIS-66    Concepción      Chile
# 4  CIUDAD-600   PAIS-66      Santiago      Chile
# 5  CIUDAD-500   PAIS-83          Lima       Perú
# 6  CIUDAD-700  PAIS-100         Quito    Ecuador
#    IDCliente NombreCliente CodigoPedido   ID Ciudad IDProducto FechaVenta  \
# 0     111225    Jumbo/Easy       159037  CIUDAD-200        IP2 2005-01-08
# 0     111225    Jumbo/Easy       159038  CIUDAD-200        IP3 2005-01-08
# 0     111225    Jumbo/Easy       159039  CIUDAD-200        IP4 2005-01-08
# 0     111225    Jumbo/Easy       159040  CIUDAD-200        IP5 2005-01-08
# 0     111225    Jumbo/Easy       159041  CIUDAD-200        IP6 2005-01-08
# ..       ...           ...          ...         ...        ...        ...
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
from dateutil.parser import parse
from pprint import pprint
import sys

# %%
def get_exchange_list_xrates(currency, amount=1):
    # make the request to x-rates.com to get current exchange rates for common currencies
    content = requests.get(f"https://www.x-rates.com/table/?from={currency}&amount={amount}").content
    # initialize beautifulsoup
    soup = bs(content, "html.parser")
    # get the last updated time
    price_datetime = parse(soup.find_all("span", attrs={"class": "ratesTimestamp"})[1].text)
    # get the exchange rates tables
    exchange_tables = soup.find_all("table")
    exchange_rates = {}
    for exchange_table in exchange_tables:
        for tr in exchange_table.find_all("tr"):
            # for each row in the table
            tds = tr.find_all("td")
            if tds:
                currency = tds[0].text
                # get the exchange rate
                exchange_rate = float(tds[1].text)
                exchange_rates[currency] = exchange_rate        
    return price_datetime, exchange_rates

# %%
source_currency = "CAD"
amount = float(1)
target_currency = "CLP"
price_datetime, exchange_rates = get_exchange_list_xrates(source_currency, amount)
print("Last updated:", price_datetime)
pprint(exchange_rates['Chilean Peso'])
# Out:
# Last updated: 2022-03-07 14:45:00+00:00
# 631.761864

# %%
print(type(exchange_rates['Chilean Peso']))
# Out:
# <class 'float'>

# %%
df_join_final['CostoUnitarioCLP'] = df_join_final['CostoUnitarioCAD']*exchange_rates['Chilean Peso']
df_join_final['PrecioUnitarioCLP'] = df_join_final['PrecioUnitarioCAD']*exchange_rates['Chilean Peso']

# %%
df_join_final
# Out:
#    IDCliente NombreCliente CodigoPedido   ID Ciudad IDProducto FechaVenta  \
# 0     111225    Jumbo/Easy       159037  CIUDAD-200        IP2 2005-01-08
# 0     111225    Jumbo/Easy       159038  CIUDAD-200        IP3 2005-01-08
# 0     111225    Jumbo/Easy       159039  CIUDAD-200        IP4 2005-01-08
# 0     111225    Jumbo/Easy       159040  CIUDAD-200        IP5 2005-01-08
# 0     111225    Jumbo/Easy       159041  CIUDAD-200        IP6 2005-01-08
# ..       ...           ...          ...         ...        ...        ...
# 10    191221      Megamaxi       184184  CIUDAD-700         MG 2015-12-08
# 10    191221      Megamaxi       184185  CIUDAD-700         MX 2015-12-08
# 10    191221      Megamaxi       184186  CIUDAD-700        SXU 2015-12-08
# 10    191221      Megamaxi       184187  CIUDAD-700        AO1 2015-12-08
# 10    191221      Megamaxi       184188  CIUDAD-700        LGP 2015-12-08
#
#     Unidades IDProducto ID Categoria NombreProducto  CostoUnitarioCAD  \
# ...

# %%
#Conector: redshift+psycopg2
#Servidor = (Dirección del Endpoint) redshift-cluster-1.cy8jk0o5flqq.sa-east-1.redshift.amazonaws.com
#Puerto=5439
#User=awsuser
#Password=Admin.2022
#Database=supertiendabi
#!pip install psycopg2

aws_engine = create_engine('redshift+psycopg2://awsuser:Admin.2022@redshift-cluster-1.cy8jk0o5flqq.sa-east-1.redshift.amazonaws.com:5439/supertiendabi')

# %%
df_join_final.to_sql('pedidos_leonardoandrade_grupo1', aws_engine, index=False, if_exists='replace')
